# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn

# %%
df=pd.read_csv('content\HR_dataset.csv')

# %%
df.head(5)

# %%
df.tail(5)

# %%
df.shape

# %%
df=df.drop_duplicates()

# %%
df.shape

# %%
df.count()

# %%
print(df.isnull().sum())

# %%
med=np.nanmedian(df['number_of_projects'])
df['number_of_projects'].fillna(med,inplace=True)
med=np.nanmedian(df['avg_monthly_hours'])
df['avg_monthly_hours'].fillna(med,inplace=True)

# %%
df=df.dropna()

# %%
print(df.isnull().sum())

# %%
df.shape
# Out:
# (11342, 10)

# %%
df.dtypes

# %%
df=df.drop(['Department'],axis=1)

# %%
sns.countplot(x='has_left_company',data=df)
plt.show()

# %%
df=df.iloc[:-6000]
df=df.reset_index(drop=True)
df.count()

# %%
sns.countplot(x='has_left_company',data=df)
plt.show()

# %%
df['salary_level']=df['salary_level'].map({'low':1,'medium':2,'high':3})

# %%
plt.subplots(figsize=(20, 10))
sns.heatmap(df.corr(),cmap = "YlGnBu",annot=True, fmt=".2f")
plt.show()

# %%
df.corr()

# %%
df.shape

# %%
df.dtypes

# %%
df.head(5)

# %%
df.describe()

# %%
plt.boxplot(df['number_of_projects'],patch_artist='b')
plt.title('years_at_company')
plt.show()

# %%
df.shape

# %%
x=df.drop('has_left_company',axis=1)
y=df['has_left_company']

# %%
x.shape

# %%
y.shape
# Out:
# (5342,)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test= train_test_split(x,y,test_size=.20,random_state=5)

# %%
x_train

# %%
y_train

# %%
x_test

# %%
# Import model
from sklearn.linear_model import LogisticRegression

print('Logistic Regression')
# Create instance of model
log_reg = LogisticRegression()

# Pass training data into model
log_reg.fit(x_train, y_train)

# %%
from sklearn.metrics import accuracy_score,precision_score,f1_score,confusion_matrix,recall_score
# prediction from the model
y_pred_log_reg = log_reg.predict(x_test)
# Score It

print('Logistic Regression')
# Accuracy
print('--'*30)
log_reg_accuracy = round(accuracy_score(y_test, y_pred_log_reg) * 100,2)

print('Accuracy ---->', log_reg_accuracy,'%')
print('Precision Score ---->',precision_score(y_test,y_pred_log_reg,average='weighted'))
print('Recall Score ---->',recall_score(y_test,y_pred_log_reg,average='weighted'))
print('F1 Score ---->',f1_score(y_test,y_pred_log_reg,average='weighted'))
con=confusion_matrix(y_test,y_pred_log_reg)
sns.heatmap(con, annot=True, fmt="d")
plt.show()

# %%
from sklearn.tree import DecisionTreeClassifier
print('Decision Tree Classifier')
# Create instance of model
Dtree = DecisionTreeClassifier()

# Pass training data into model
Dtree.fit(x_train, y_train)

# %%
from sklearn.metrics import accuracy_score,precision_score,recall_score,f1_score,confusion_matrix
y_pred_Dtree = Dtree.predict(x_test)
# Score It

print('Decision Tree Classifier')
# Accuracy
print('--'*30)
Dtree_accuracy = round(accuracy_score(y_test, y_pred_Dtree) * 100,2)
print('Accuracy ---->', Dtree_accuracy,'%')
print("Precision Score ---->",precision_score(y_test,y_pred_Dtree,average='weighted'))
print("Recall Score---->",recall_score(y_test,y_pred_Dtree,average='weighted'))
print("F1 Score---->",f1_score(y_test,y_pred_Dtree,average='weighted'))
con=confusion_matrix(y_test,y_pred_Dtree)
sns.heatmap(con, annot=True, fmt="d")
plt.show()

# %%
from sklearn.ensemble import RandomForestClassifier

print('Random Forest Classifier')
# Create instance of model
rfc = RandomForestClassifier()

# Pass training data into model
rfc.fit(x_train, y_train)

# %%
from sklearn.metrics import accuracy_score,precision_score,recall_score,f1_score,confusion_matrix
y_pred_rfc = rfc.predict(x_test)
# Score It

print('RFC Tree Classifier')
# Accuracy
print('--'*30)
rfc_accuracy = round(accuracy_score(y_test, y_pred_rfc) * 100,2)
print('Accuracy ---->', rfc_accuracy,'%')
print("Precision Score ---->",precision_score(y_test,y_pred_rfc,average='weighted'))
print("Recall Score---->",recall_score(y_test,y_pred_rfc,average='weighted'))
print("F1 Score---->",f1_score(y_test,y_pred_rfc,average='weighted'))
con=confusion_matrix(y_test,y_pred_rfc)
sns.heatmap(con, annot=True, fmt="d")
plt.show()

# %%
data=zip(y_test,y_pred_rfc)
df = pd.DataFrame(data, columns=["Actual","Predicted"])
df.head(10)

# %%
df.tail(10)
# Out:
#       Actual  Predicted
# 1059       0          0
# 1060       0          0
# 1061       0          0
# 1062       0          0
# 1063       0          0
# 1064       0          0
# 1065       0          0
# 1066       0          0
# 1067       1          1
# 1068       1          1

# %%
from sklearn.ensemble import GradientBoostingClassifier

print('Gradient Boosting Classifier')
# Create instance of model
gbc = GradientBoostingClassifier()

# Pass training data into model
gbc.fit(x_train, y_train)
# Out:
# Gradient Boosting Classifier
# GradientBoostingClassifier()

# %%
from sklearn.metrics import accuracy_score,precision_score,recall_score,f1_score,confusion_matrix
y_pred_gbc = gbc.predict(x_test)
# Score It

print('GBC Classifier')
# Accuracy 
print('--'*30)
gbc_accuracy = round(accuracy_score(y_test, y_pred_gbc) * 100,2)
print('Accuracy ---->', Dtree_accuracy,'%')
print("Precision Score ---->",precision_score(y_test,y_pred_gbc,average='weighted'))
print("Recall Score---->",recall_score(y_test,y_pred_gbc,average='weighted'))
print("F1 Score---->",f1_score(y_test,y_pred_gbc,average='weighted'))
con=confusion_matrix(y_test,y_pred_gbc)
sns.heatmap(con, annot=True, fmt="d")
plt.show()

# %%
from sklearn.svm import SVC
svm=SVC(kernel='linear')
print("SVM")
svm.fit(x_train,y_train)
# Out:
# SVM
# SVC(kernel='linear')

# %%
from sklearn.metrics import accuracy_score,precision_score,recall_score,f1_score,confusion_matrix
y_pred_svm = svm.predict(x_test)
# Score It

print('SVM Classifier')
# Accuracy
print('--'*30)
svm_accuracy = round(accuracy_score(y_test, y_pred_svm) * 100,2)
print('Accuracy ---->', Dtree_accuracy,'%')
print("Precision Score ---->",precision_score(y_test,y_pred_svm,average='weighted'))
print("Recall Score---->",recall_score(y_test,y_pred_svm,average='weighted'))
print("F1 Score---->",f1_score(y_test,y_pred_svm,average='weighted'))
con=confusion_matrix(y_test,y_pred_svm)
sns.heatmap(con, annot=True, fmt="d")
plt.show()

# %%
from sklearn.neighbors import KNeighborsClassifier
knn=KNeighborsClassifier()
print("KNN")
knn.fit(x_train,y_train)

# %%
from sklearn.metrics import accuracy_score,precision_score,recall_score,f1_score,confusion_matrix
y_pred_knn = knn.predict(x_test)
# Score It

print('KNN Classifier')
# Accuracy
print('--'*30)
knn_accuracy = round(accuracy_score(y_test, y_pred_knn) * 100,2)
print('Accuracy ---->', knn_accuracy,'%')
print("Precision Score ---->",precision_score(y_test,y_pred_knn,average='weighted'))
print("Recall Score---->",recall_score(y_test,y_pred_knn,average='weighted'))
print("F1 Score---->",f1_score(y_test,y_pred_knn,average='weighted'))
con=confusion_matrix(y_test,y_pred_knn)
sns.heatmap(con, annot=True, fmt="d")
plt.show()
